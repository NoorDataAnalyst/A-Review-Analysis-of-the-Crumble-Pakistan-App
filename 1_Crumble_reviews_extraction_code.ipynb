# %%
# !pip install google-play-scraper
from google_play_scraper import app,Sort, reviews_all
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.3 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
# from google_play_scraper import
pak_review = reviews_all("com.blink.crumblecookies")

# %%
df = pd.DataFrame(np.array(pak_review), columns=['review'])
df = df.join(pd.DataFrame(df.pop('review').tolist()))
df
# Out:
#                                  reviewId              userName  \
# 0    c600a859-237c-487e-a94f-3d65a0788bd8            hina karim
# 1    9351c10e-0719-42cf-9d82-da5cbd1393dd       Free Time Ideas
# 2    1f067eb2-c5c3-4c8d-ba60-68f2237e4f6d           malik usman
# 3    03ef3836-7257-4cc0-9fb2-827ed75900a6        Arsalan Qadeer
# 4    84c9d31e-c134-4c45-82fb-6d73196df028         rabyia sultan
# ..                                    ...                   ...
# 271  73cfe0fd-92e9-489e-b044-76e7063a67c2             Imaan Jan
# 272  a0b19bcf-e60a-451b-8ab6-a56a12555b1c  Abdurrahman bin Omer
# 273  e35ca69f-1e6f-49d0-9d19-c6d13adcb2ce     AbdullahUmarZahid
# 274  0e3da49b-6e90-43ad-9d43-4bd038015f68          Ahmed Farhan
# 275  70fe11cf-f762-41f3-ab6b-14e2fd237310            Areeb Umer
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/a/ACg8oc...
# 1    https://play-lh.googleusercontent.com/a-/ALV-U...
# 2    https://play-lh.googleusercontent.com/a-/ALV-U...
# 3    https://play-lh.googleusercontent.com/a/ACg8oc...
# 4    https://play-lh.googleusercontent.com/a/ACg8oc...
# ..                                                 ...
# 271  https://play-lh.googleusercontent.com/a-/ALV-U...
# 272  https://play-lh.googleusercontent.com/a-/ALV-U...
# 273  https://play-lh.googleusercontent.com/a/ACg8oc...
# 274  https://play-lh.googleusercontent.com/a/ACg8oc...
# 275  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                                content  score  thumbsUpCount  \
# 0                                                  fan      5              0
# 1    I could not get otp code on the phone number a...      2              0
# 2    today I tried cold drink first time. cloud noi...      1              0
# 3    That sounds incredibly frustrating and disorga...      1              0
# 4    most ridiculous system of take away they force...      1              0
# ..                                                 ...    ...            ...
# 271                                           Besttttt      4              1
# 272                    Really amazing and use friendly      5              1
# 273  Great App. Best Cookies on the planet. Easiest...      5              7
# 274  Best cookies in cookies in Islamabad/Rawlpindi...      5              6
# 275  Works perfectly. I have ordered a couple of ti...      5              7
#
#     reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                  1.3.4 2026-06-11 15:06:35         None      None      1.3.4
# 1                  1.3.4 2026-06-10 18:49:30         None      None      1.3.4
# 2                  1.3.4 2026-06-07 18:17:05         None      None      1.3.4
# 3                  1.3.4 2026-06-05 20:53:08         None      None      1.3.4
# 4                  1.3.4 2026-06-05 19:19:43         None      None      1.3.4
# ..                   ...                 ...          ...       ...        ...
# 271                1.0.7 2023-06-23 13:24:42         None      None      1.0.7
# 272                1.0.7 2023-06-20 08:28:07         None      None      1.0.7
# 273                1.0.7 2023-06-12 11:30:51         None      None      1.0.7
# 274                1.0.7 2023-06-12 09:37:06         None      None      1.0.7
# 275                1.0.7 2023-06-12 08:38:45         None      None      1.0.7
#
# [276 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              276 non-null    object
#  1   userName              276 non-null    object
#  2   userImage             276 non-null    object
#  3   content               276 non-null    object
#  4   score                 276 non-null    int64
#  5   thumbsUpCount         276 non-null    int64
#  6   reviewCreatedVersion  236 non-null    object
#  7   at                    276 non-null    datetime64[ns]
#  8   replyContent          0 non-null      object
#  9   repliedAt             0 non-null      object
#  10  appVersion            236 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(8)
# memory usage: 23.8+ KB

# %%
df.to_csv('Crumble_reviews.csv', index=False)
